# %%
#This file is try to remove the duplicate
import pandas as pd
df = pd.read_csv("foursquare.csv")
df = df.drop_duplicates("id")
df.to_csv("foursquare_nonduplicate.csv", sep=',')

# %%
df
# Out:
#       Unnamed: 0                                   name  \
# 0              0                Szechuan Garden Kitchen
# 1              1                                Red Hot
# 2              2                   Hunan Chen's Kitchen
# 3              3                         Peking Kitchen
# 4              4               No. 1 Chinese Restaurant
# 5              5                        Jimmy's Chinese
# 6              6  Empire III Chinese & Pan Asian Cusine
# 7              7                       Empire Corner II
# 8              8                             Good Taste
# 9              9                           New King Wok
# 10            10                  Red Star Chinese Food
# 11            11                             New Dragon
# 12            12                Feng Shun Chang Kitchen
# 13            13                            Hong Cheong
# 14            14                          Junzi Kitchen
# 15            15                  Crispy Bamboo Village
# ...
